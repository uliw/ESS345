# %% [markdown]
# ## Variables II

# %% [markdown]
# In the previous module, we learned how to:
#
# 1.  assign a label and value to a memory location
# 2.  retrieve value from a memory location using the label as
#     reference
# 3.  That the variables we use have a superficial semblance to symbolic
#     math, but behave rather differently and allow us to write
#     expressions like `a = a + 1`
# 4.  Implicit in the last module, you saw that we can write values into
#     a memory location either directly (`a=2`), or as a result of
#     another expression (a= a\*2)
# 5.  We played with some math operators
#
# In this module, we will explore the use of variables in more detail.

# %% [markdown]
# ### Variable names

# %% [markdown]
# In principle python variables can have any name you like. However,
# there are some time tested best practices:
#
# 1.  Variable names must start with a letter
# 2.  Variable names can only contain letters, numbers, and underscores
#     (i.e., no blank spaces or special symbols)
# 3.  Avoid variable names which are too general or too wordy. E.g.,
#     rather than `my_first_variable` call it `length` or any other
#     descriptive term.
# 4.  Avoid letters like "I" or "O" where it is hard to know whether you
#     mean lowercase "I", upper case "I", or the number "1", similarly,
#     "O" is easily confused with zero
# 5.  Variables names should always be lower case
# 6.  Compound names should always be connected by an underscore. i.e.,
#     `student_id` rather than `student-id` which could be interpreted as
#     `student` minus `id`
# 7.  And it is always a good idea to add some comments which explain
#     what your variable means (more on this later)
# 8.  If in doubt, google "Python Naming Conventions"

# %% [markdown]
# ### Assignment

# %% [markdown]
# Create a new notebook with the headline "ESS345 Computational Geology:
# Variables - II" You did create template last time, so this should be
# straight forward, including the notebook name and location. If not,
# this is now a good time to speak up!
#
# Delete all your cells, and add a new python 3 cell below the headline
# and enter the following snippet
#
#     a=4
#     b=5
#     c=10
#     a= (a/b)*c
#     print(a)
#
# execute this code, and add a text cell, and explain why "a" equals 8
# and not 4 (it is not about the math!)
#
# Left click on your code cell, and select the "copy" symbol from the
# menu bar, left click on your text cell, and select the paste symbol
# from the menu bar to copy the code cell. In this new code cell,
# replace `print(a)` with `print(A)` and execute your code. Please do so
# before you continue to read.
#
# Add a text-cell and describe the results of your experiment. Are
# variable names case specific or not? Mark your findings in **BOLD!**
#
# This is (hopefully), also your first encounter with python-error
# messages. They do look a bit cryptic, but are often quite
# useful. Let's take a closer look to understand what happened here:
#
# When you hit `shift+enter` you send the commands you have typed into
# the code cell to the python interpreter. This is just another computer
# program which will read your commands and try to make sense of
# it. Before running your code, the interpreter will do some sanity
# checks, and in the above case, it finds that the variable "A" was
# never defined. It thus prints:
#
# 1.  a red line
# 2.  the type of error, in this case "NameError", and some information
#     about the sequence how the errors are listed.
# 3.  the type of input (ipython) and in which cell it occurred, followed
#     by the memory address and the module name (let's ignore this for
#     the moment)
# 4.  the last couple of lines before the error occurred
# 5.  the line where the error occurred
# 6.  and if you are lucky some information why the error occurred.
#
# In your assignment, add a text cell below the code cell with the error,
# with the following content
#
#     ErrorName  =
#     Input_Type =
#     Cell_number where error occurred =
#     Memory address where error occurred =
#     Module name where error occurred =
#     Line Number where error occurred =
#     Explanation of error type =
#
# and add the data you get from the actual error message after the equal
# signs.  If you have difficulties seeing the various elements above,
# please talk to the TA or instructor
#
# OK, let's add another code cell and execute the following statement
#
#     a-b = 5
#
# your mileage may vary (YMMV) but you may either get no result at all,
# or an error message. If you get no result, go to your menu bar and
# select `Kernel -> Restart` and execute your cell again.
#
# Explain in a text cell why you get an error. Then add a new code cell
# and execute this statement
#
#     a b = 5
#
# and explain why it fails.
#
# Last but not least, execute this statement
#
#     f_g = 5
#
# Explain why this statement succeeds, and what are the values for f &
# g?
#
# Last but not least, add a final text cell, and write down what you
# learned in this module.

# %% [markdown]
# ### Marking scheme:

# %% [markdown]
# 1.  2 point if the filename follows the file-name Template (capitalization, spaces, and dashes!)
# 2.  2 points if the content is as requested.
# 3.  2 points for each text cell with the correct explanation (8 pts
#     total)
