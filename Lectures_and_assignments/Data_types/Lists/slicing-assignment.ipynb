# %% [markdown]
# ## Slicing Assignment

# %% [markdown]
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# You must copy this notebook to your submissions folder before editing
# it. Otherwise, your edits may be overwritten the next time you log
# into syzygy. Please name your copy "Slicing-Assignment-FirstName-LastName".
#
# In order to submit your assignment, you need to download it and submit
# it on Quercus.
#
# Below you will find empty code cells in which you have to enter python
# code. Please use the respective cell below each question.  Where
# necessary, add text cells to enter your answers. Your answers will
# only count if the codes executes without error. It is thus recommended
# to execute your solutions before submitting the assignment.
#
# Execute the following block so that `my_list` becomes known in your
# local Jupyter session.

# %%
my_list = [3, 4, 5, 12, 0, 11, 1, 2, 9, 8, 7, 13, 10]
# Out:
# # Out [1]:
# # output
# [3, 4, 5, 12, 0, 11, 1, 2, 9, 8, 7, 13, 10]

# %% [markdown]
# Add a textbox here, and explain why the above statement does not
# produce any output. 2pts
#
# Write three python statements (one on each line) which will show the
# first, the last and the second last element of `my_list`). 3pts

# %% [markdown]
# Write python statement which shows the last 4 elements of `my_list`
# 1pst

# %% [markdown]
# Write python statement which shows every 3rd element of `my_list`
# starting with the second element in the list. 2pts

# %% [markdown]
# Write python statement which shows every second element of the last 6
# elements in `my_list` 2pts. I suggest you first test your range
# expression with a step size of -1, to make sure yo use the correct range

# %% [markdown]
# Write python statement which shows every second element of the last 6
# elements in `my_list` in reverse order 3pts

# %% [markdown]
# What is the shortest slicing notation to show all values of `my_list` in reverse order. 2pts

# %% [markdown]
# Add a textbox below the codebox, and explain why the next two
# statements do not produce the same result 2pts

# %%
print(my_list[0:])
print(my_list[0:-1])

# %% [markdown]
# what is wrong with this python statement below? 1pt
#
#     my_list = [1 2 3]
