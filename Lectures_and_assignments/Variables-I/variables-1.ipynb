# %% [markdown]
# ### TODO

# %% [markdown]
# ## Variables

# %% [markdown]
# A computer is a device which can store and manilpulate data
# (information). Before we proceed to learn the basics of data
# manipulation, we need to understand how data is stored.
#
# On its most basic level, a computer resembles a library (you have been
# to the library, right?). There are vast amounts of storage space, a
# catalog where we can lookup where a specific book is stored, a
# librarian who will move books around and do other maintenance tasks,
# and a user who manipulates the information in those books, and who
# might writes a new book which eventually goes back into the library.
#
# Books can be found using a rather specific way of writing their
# address in the library storage which, e.g., could read
# `QA76.17.C4672012`.
#
# Similarly, information in a computer can be retrieved by using equally
# cryptic schemes, e.g., `0x5560b128f480`. This is a so number to the
# base of 16, which basically indicates that the respective data is
# stored in the 93873777472640<sup>th</sup> memory cell. Clearly, it is cumbersome
# to keep these alphanumeric sequences in mind. This is where variables
# come into play. Rather then saying store the number 4 at location
# `0x5560b128f480` we can simply say "assign the value of 4 to the
# variable a". Let's try this and execute the following statement doing
# a left-click in the following cell, and hit `shift+enter`

# %%
a = 4

# %% [markdown]
# This will produce no output, but you will have assigned the value of 4
# to the variable `a`. Let's verify that this assignment did succeed. We
# can do so asking the python interpreter to print the value
# of a. Execute this cell and you should see the result printed below
# this cell

# %%
print(a)

# %% [markdown]
# Go ahead and try this

# %%
a=4
b=5
c=10
(a/b)*c

# %% [markdown]
# So far this seems straightforward, and it likely reminds you of
# symbolic math you learned in your school years. While there are
# computing environments which can do symbolic math, the above is an
# entirely different beast. In symbolic math, the expression `a = b` is
# equal to the expression `b = a`. Not so in coding (try e.g., `a = 4`
# vs `4 = a`).  Remember, that writing `a = 4` means take the value of
# 4, store it into memory, and give this memory location the name "a". A
# better way to write this would be `a <-- 4`.
#
# Likewise the expression `a+a` means retrieve the value stored at
# location "a" and add it to the value stored at location "a". So the
# "a" is merely a reference to a memory location.  Note that there is
# nothing specific about calling this "a", You could equally write
# `myfirstvariablename = a` but it is a lot of typing
#
# So by now, you have learned two very fundamental processes:
#
# 1.  Assigning a label and value to a memory location
# 2.  Retrieving value from a memory location using the label as
#     reference
#
# Go forth, and solve this assignment:
#
# 1.  Create a new notebook, called
#     "Variables-Assignment-FirstName-LastName"
# 2.  Add a title like this "Variables Assignment FirstName LastName"
# 3.  Date
# 4.  Student Id (probably easiest if you copy your notebook from the
#     previous exercise)
# 5.  Add a text cell and cut copy past this text
#
#     Assume that
#     a = 4
#
#     if you now write
#     a = a + 1
#
#     what would you get if you execute print(a) afterwards?
#     Please consider this first without executing this.
#     Write down your expected result, and explain why you expect this.
#
# 1.  add a `python 3` cell to your notebook, and execute the above
# 2.  add a another text cell, and write down the expected value vs the
#     observed value. If they are different, can you explain why? And if
#     you can't explain it, could you speculate? Please write down your
#     thoughts, and submit this notebook on quercus.
#
# Marking scheme:
#
# 1.  3 points if the filename follows the file-name Template (capitalization, spaces, and dashes!)
# 2.  2 points if the content is as requested.
# 3.  2 points if you have the correct (or internally consistent
#     explanation) of the above experiment (even if your expected result
#     was different from the one you obtained in the experiment)
#
#
# [literatur/journals-new.bib,literatur/new.bib,literatur/uli.bib,literatur/uli-with-students.bib](literatur/journals-new.bib,literatur/new.bib,literatur/uli.bib,literatur/uli-with-students.bib)
