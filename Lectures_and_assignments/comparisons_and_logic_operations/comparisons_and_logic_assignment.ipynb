# %% [markdown]
# ### TODO

# %% [markdown]
# assignment is to short

# %% [markdown]
# ## Comparisons and Logic Operators Assignment

# %% [markdown]
# You must copy this notebook to your submissions folder before editing
# it. Otherwise, your edits may be overwritten the next time you log
# into syzygy. Please name your copy
# "comparisons-FirstName-LastName".
#
# In order to submit your assignment, you need to download it and submit
# it on Quercus. You can delete this and the preceding paragraph
# afterwards.
#
# Note, most of the text below renders as a single text cell. Thus it is
# not easy to answer the questions with more text of you own. However,
# you can split the existing text. Click the text cell you want to
# split, position the cursor to where you want to the split occur, and
# press the following keys at the same time "shift enter minus".  Leave
# the edit mode with shift enter, and you can now insert a new text cell
# with your answer below. Please use this method from now on.
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# All questions should be solved with the techniques introduces in the
# last module.
#
# 1.  The results of comparisons are reported as the logical (boolean)
#     values of either `True`, or `False`. Internally they are
#     represented by a single bit wich is either 1 or 0. Use a comparison
#     operator to investigate how `True` or `False` relate to the
#     numerical values of 0 and 1 (2pts)

# %%
#

# %% [markdown]
# 1.  Does capitalization of the word `true` matter? What happens if you
#     change the capitalization. And how does your notebook indicate that
#     `True` has a special meaning? (2pts)
# 2.  Being mindful of the fact that integer numbers are different than
#     floating point numbers, predict the outcome of the following
#     comparison (1pt)
#
#         a = 12
#         b = 12.0
#         a == b
# 3.  Edit the following lines and add the boolean value (i.e.,
#     True/False) for each statement after the hash symbol. Note, do not
#     enter code code here, your answer should be a textcell. You are
#     welcome to use code in order to test your answers, but it should
#     not be part of your answer (10pts).
#
#         5 == 4        #
#         2 != 3        #
#         5 > 4         #
#         5 < 4         #
#         1 >= 1        #
#         2 <= 2        #
#         -12 < -4      #
#         True == True  #
#         True != False #
#         True != true  #
#         True > False  #
#
# 4.  Edit the following lines and add the boolean value (i.e.,
#     True/False) for each statement after the hash symbol. Note, do not
#     enter code code here, your answer should be a textcell. You are
#     welcome to use code in order to test your answers, but I strongly
#     recommend to first solve this on paper. Again, the answer requires
#     no code.  (9pts).
#
#         True and True             #
#         True and False            #
#         False and False           #
#         False or True             #
#         True or False             #
#         not(True) or not(False)   #
#         not(True or False)        #
#         not(True) and not(False)  #
#         not(True and False)       #
#
# 5.  Edit the following lines and add the boolean value (i.e.,
#     True/False) for each statement after the hash symbol. Note, do not
#     enter code code here, your answer should be a textcell. You are
#     welcome to use code in order to test your answers, but I strongly
#     recommend to first solve this on paper. Again, the answer requires
#     no code.  (8pts).
#
#         a = 5
#         b = 12
#         a > 0 and b > 0       #
#         a < 0 and b > 0       #
#         a < 0 or  b > 0       #
#         a < 0 or  b < 0       #
#         not(a < 0) and  b > 0 #
#         not(a < 0) or   b > 0 #
#         not(a < 0 or b > 0)   #
#         not(a < 0 and b > 0)  #
