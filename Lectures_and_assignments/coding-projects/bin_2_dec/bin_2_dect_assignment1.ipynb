# %% [markdown]
# ## Binary to decimal conversion assignment

# %% [markdown]
# ### New techniques to be used in this assignment

# %% [markdown]
# #### Python Doc Strings

# %% [markdown]
# You already encountered the hashtag sign, which signifies a comment in
# the code (i.e., everything after the hashtag is ignored). Python
# provides a second mechanism to add comments into the code, the so
# called "doc-strings". Unlike regular comments, doc-strings will be
# used by the `help()` command, and they can span multiple lines. Going
# forward, each of your programs (as opposed to snippets) should start
# with a doc-string which contains a short text what the program does,
# and how to use it, and who authored it. Doc-string start and end with
# triple quotation marks. Doc-strings should only be used at the
# beginning of a program. We will later explore how doscstrings are used in
# functions.

# %%
""" This is a single line doc-string"""
"""
This is a multiline docs string.

If you want to seprate a paragraph, you need to leave an empty line.
"""

# %% [markdown]
# #### Type hinting

# %% [markdown]
# Python is a dynamically typed language. That is, the type of the
# variable (int, float, string), is determined at the time you assign it
# a value. Reading code written by other people, it is thus often
# difficult to understand what the code is doing. Python provides the so
# called type hints, to help with this situation. Typically, this is
# overkill for a short script, but the minute you start working on
# larger projects, or in a team, it greatly helps clarity. We will
# therefore use it here from the very beginning.

# %%
a = 12
l = [1, 4, 6]
t = (4, 9, 1)
s = ""
# This can be also be written
a :int   = 12
l :list  = [1, 4, 6]
t :tuple = (4, 9, 1)
s :str   = ""

# %% [markdown]
# This will not prevent you from doing something like this:

# %%
a :int   = 12
a = "ssdsd"

# %% [markdown]
# but your code will become more readable. Also, some automatic syntax
# checkers will then flag the second line. So as a baseline, whenever
# you declare a variable, use type hinting from now on.

# %% [markdown]
# ### Assignment

# %% [markdown]
# Using a new notebook, write python code which will convert an
# arbitrary binary number into its decimal form, and print the result on
# the screen. Your code should not use pythons builtin conversion
# function, rather, it should convert the binary number itself (27 pts).
#
# Your code should use the supplied code template. The marking is as
# follows:
#
# -   Correct notebook name: 1pt
# -   Required notebook header 1pt
# -   Code planning: 9 pts, one for each subsection with the exception of
#     Data-structures (2pt), and Pseudo-code (4pt)
# -   Code:
#     -   Proper docstring 2pts
#     -   Correct variables definitions (3pt total, 1 pt each)
#     -   Type hinting used throughout
#     -   Working code: 4pt
#     -   Result printed: 5pt
