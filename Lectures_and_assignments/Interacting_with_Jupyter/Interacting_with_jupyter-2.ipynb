# %% [markdown]
# ## ESS345 Computational Geology: Interacting with Jupyter 2

# %% [markdown]
# In the previous exercise you learned
#
# 1.  How to access the Jupyter server
#     1.  How to create and name folders (directories) on the Jupyter server
#     2.  How to upload a Jupyter Notebook
#     3.  How to Name a Jupyter Notebook
#
# The Jupyter notebook we used as example, was not very exciting, and
# only displayed some text.  Since Jupyter notebooks will be the primary
# tool we use in this course, and the dominant format for your
# assignment submissions, we will explore their use in greater detail.
#
# A Jupyter notebook has 3 principal elements
#
# 1.  Text areas (often referred to a cells)
# 2.  Code blocks (or code cells)
# 3.  Result Blocks
#
# If you do a single left click with your mouse on this text, you will
# see that this cell is now drawn with a black border and a blue marker
# on the left. This indicates that the cell has been selected.
#
# If you double left click on the cell, you will see that the cell
# background changes to gray and the text will be rendered in a
# typewriter font. This indicates that you are now in editing Mode. You
# can leave the editing mode any time by hitting shift-Enter.

# %% [markdown]
# ##### Formatting Text

# %% [markdown]
# Formatting text is done with a few simple commands using the "Markdown
# Syntax". Double click on this cell to see some typical elements
#
# 1.  This is **bold** text
# 2.  This is a simple list
#     -   First list entry
#     -   Second list entry
# 3.  This is the 3rd entry in the enumerated list, and has no other
#     purpose than just being the 3rd entry.
#
# You may have noted that the list nesting is achieved by simply
# indenting the text after "This is a simple list". There are many more
# formatting options, but for this course, we likely won't need them,
# but feel free to have a look at [this link](https://guides.github.com/features/mastering-markdown/)

# %% [markdown]
# #### Assignment # 1 - Text cells

# %% [markdown]
# Enough theory! Without further ado, let's create a new notebook of
# your own. Go to your "ESS345 Computational Geology"/"Interacting with
# Jupyter" folder and Left click on the `New` button in the upper right
# corner. Select `Python 3` to create a new notebook. Once the new
# notebook has opened, left click on `File` and then select "Rename" and
# Name your file according to the following Scheme
#
# `FirstName-Lastname-text-edit-assignment`
#
# In the middle of the menu bar, you will see the word `Code` just
# right of the double right arrow. This box tells you that the first
# (and currently empty cell) is a code box. You can change the cell type
# by left clicking on `Code`, or by using the `Cell` menu.
#
# 1.  Go ahead and change it to "Markdown"
# 2.  Now add the following text to this cell "Editing Text in a Jupyter Notebook"
# 3.  Save your edits by hitting `shift+enter`
# 4.  Select this cell again (double left click) and now modify the text
#     using markdown syntax in such a way that it becomes a level 1
#     heading (see above).
# 5.  Click above on "Formatting Text" to see how to insert a heading
#
# If you already have a new cell below the heading, change it to
# markdown mode (see above), or insert a new cell
# (`Insert -> Cell below`) and change it to markdown afterwards.
#
# In this cell, add the following text
#
#     ESS345 Computational Geology Text Cell Assignment
#
#     Date:
#
#     First Name:
#
#     Last Name:
#
#     Student: Id
#
# Change the first line into a level 1 Heading,
#  add the date, your first and last name and your student id after the
# colon. Now change the formatting in such away that the text before the
# colon is set in bold, whereas your personal info is set in a regular
# font.
#
# Last but not least, save your edits using the disk icon just under the
# `File` menu, and then download your notebook in `Notebook` format
# (`File -> Download as`), and submit it on Quercus.
#
# Auto

# %% [markdown]
# #### Assignment # 2 - Code cells

# %% [markdown]
# Save your previous notebook as
# `FirstName-Lastname-code-cell-assignment` And open it. Now, change the
# heading in such a way that it reads "Creating and executing a code
# cell". Add a new cell below your personal details, and make sure it is
# a code cell.
#
# Enter a trivial statement like `1 + 1` and hit `shift-enter` and you
# should see the result being displayed below the code cell. Go ahead
# and edit your code cell (e.g., 1+3) and hit =shift+enter" again. The
# result should change accordingly.
#
# Save your notebook, and download it, and submit on querulous.

# %% [markdown]
# ### Marking Scheme

# %% [markdown]
# 1.  3 points if the filename follows the file-name Template (capitalization, spaces, and dashes!)
# 2.  2 points if the content is as requested.

# %% [markdown]
# ### Recap

# %% [markdown]
# In this module, you learned how-to:
#
# 1.  Create a notebook
# 2.  Save a notebook
# 3.  Download a notebook
# 4.  Create text cells
# 5.  Edit and format text cells
# 6.  Create code cells
# 7.  Execute code in a code cell
